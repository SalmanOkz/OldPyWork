# %%
def table():
  for i in range(1,4):
    for j in range(1,2):
      print(i*j)

table()
# Out:
# 1
# 2
# 3

# %%
def increment(number,by):
    return number + by


increment(2,4)
# Out:
# 6

# %%
def num(*numbers):
    total=2
    for number in numbers:
        total *= number
    return total


print(num(2,3,4))
num()
# Out:
# 48
# 2

# %%
def some(**user):
    print(user)

some(name="muhammad",id=9922,lname="salman")
# Out:
# {'name': 'muhammad', 'id': 9922, 'lname': 'salman'}

# %%
def fizz_buzz():
    numbers=int(input("Enter any number: "))
    number_list(str(numbers))
    for number in numbers:
        print(number)
        if number == 3:
            print("fizz")
        elif number == 5:
            print("buzz")
        elif number == 3 and 5:
            print("fizz buzz")
        else:
            print("Enter valid number:")


fizz_buzz()
# Out:
# Enter any number:  3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 16
#      12         else:
#      13             print("Enter valid number:")
# ---> 16 fizz_buzz()
#
# Cell In[37], line 3, in fizz_buzz()
#       1 def fizz_buzz():
#       2     numbers=int(input("Enter any number: "))
# ----> 3     number_list(str(numbers))
#       4     for number in numbers:
#       5         print(number)
#
# NameError: name 'number_list' is not defined

# %%
number = 4
for number in range(0,4):
    print(number * ".")
# Out:
# .
# ..
# ...

# %%
zoo_animals = [["share","big"],["big","cat"]]
for animal in zoo_animals:
    print(animal)
# Out:
# ['share', 'big']
# ['big', 'cat']

# %%
msg=input("Enter the sentence: ")
shift = int(input("by how many character you want it to be in: :"))
for letter in msg:
    print(letter)
    if letter.isalpha():
        letters="abcdefghijklmnopqrstuvwxyz"
        if letter.isupper():
            letters="ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        position = letters.find(letter)
        shift_position=(position + shift)%26
# Out:
# Enter the sentence:  sass
# by how many character you want it to be in: : 2
# s
# a
# s
# s

# %%
#lambda function to calculate the product of 2 numbers with additional print statement using formatted string
                   # here f represents formatted string statement
multiply=   lambda x,y:print(f"{x} *{y}={x*y}")         # assigning lambda function to multiply
multiply(3,4)
# Out:
# 3 *4=12

# %%
age=[23,23,23,23,23]
multi=list(map(lambda a: a*a,age))
print(multi)
# Out:
# [529, 529, 529, 529, 529]

# %%
items=[
    ("product",2),
    ("PC",3),
    ("PC",3)
]
pro=[]
for item in items:
    pro.append(item[0:1])

print(pro)

prince=list(map(lambda item: item[1]>20,items))
print(pro)

filtered=list(filter(lambda item: item[1] > 2,ages))
print(filtered)
# Out:
# [('product',), ('PC',), ('PC',)]
# [('product',), ('PC',), ('PC',)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 15
#      12 prince=list(map(lambda item: item[1]>20,items))
#      13 print(pro)
# ---> 15 filtered=list(filter(lambda item:item[1]>2,ages))
#      16 print(filtered)
#
# TypeError: 'int' object is not iterable

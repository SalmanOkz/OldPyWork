# %%
board=[[""for _ in range(5)] for _ in range(5)]

def print_board():
    for row in board:
        print(" | ".join(row))
        print("-" * 13)


print_board()
# Out:
#  |  |  |  |
# -------------
#  |  |  |  |
# -------------
#  |  |  |  |
# -------------
#  |  |  |  |
# -------------
#  |  |  |  |
# -------------

# %%
def evaluation(board):
    return sum(1 for row in borad for cell if cell == 'X') - sum(1 for row in board for cell if cell == 'O')

# %%
def alphabeta(board,alpha,beta,maximizing_player,depth):
  if wining == 'X':#x wining
    return 1 - depth
  elif wining == 'O':#o wining 
    return depth - 1
  elif depth == 0:#draw
    return evaluate

  if maximing_player:
    max_eval = float(-inf)
    for move in genrated_player(board):
        max_eval = max(move,depth - 1,alpha,beta,True)
        alpha = max(alpha,eval)
        if beta<=alpha:
            break
        reutrn max_eval
